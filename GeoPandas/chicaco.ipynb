# %%
import geopandas as gpd

gdf = gpd.read_file('chicago.geojson')

# %%
gdf
# Out:
#                   name  cartodb_id                       created_at  \
# 0      Grand Boulevard           1 2013-02-02 23:59:44.022000+00:00
# 1         Printers Row           2 2013-02-02 23:59:44.022000+00:00
# 2        United Center           3 2013-02-02 23:59:44.022000+00:00
# 3   Sheffield & DePaul           4 2013-02-02 23:59:44.022000+00:00
# 4        Humboldt Park           5 2013-02-02 23:59:44.022000+00:00
# ..                 ...         ...                              ...
# 93   Ukrainian Village          94 2013-02-02 23:59:44.022000+00:00
# 94            Old Town          95 2013-02-02 23:59:44.022000+00:00
# 95          Gold Coast          96 2013-02-02 23:59:44.022000+00:00
# 96            Boystown          97 2013-02-02 23:59:44.022000+00:00
# 97         River North          98 2013-02-02 23:59:44.022000+00:00
#
#                          updated_at  \
# 0  2013-02-02 23:59:44.295000+00:00
# 1  2013-02-02 23:59:44.295000+00:00
# 2  2013-02-02 23:59:44.295000+00:00
# ...

# %%
import matplotlib

gdf.plot()
# Out:
# <Axes: >

# %%
import pandas as pd

df = pd.read_csv('https://data.cityofchicago.org/resource/e55j-2ewb.csv')

# %%
df.head()
# Out:
#                                     trip_id  \
# 0  0fca59218b11688279d795c03c4d16f851f13fa0
# 1  1e539d6e7501164c6b76b761c3152c235e206d59
# 2  2b3c5200439d51f626b60380809bbbcca766a85b
# 3  45b2ea39cfff64d61a46ef016e16f8ee74e9ed23
# 4  464df6aaaf97ca8745985c2a5b2e481067a2bfb6
#
#                                              taxi_id     trip_start_timestamp  \
# 0  e2c349c7cbb608d552aa0b5814031943f13641ef9e50d8...  2023-01-01T00:00:00.000
# 1  4ab7a7510c1ebcc9b2e3eaa7bdd6508dbea34da7986aca...  2023-01-01T00:00:00.000
# 2  8c76eb82f069c0731a0049cb78898f02cc5ac6990244c9...  2023-01-01T00:00:00.000
# 3  a688de71e9eb70603ba839dc7faf949968ae3e971e0575...  2023-01-01T00:00:00.000
# 4  8b1a88e5a09cfd55ca72d267f00f56fa50a42aa322bdfe...  2023-01-01T00:00:00.000
#
#         trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0  2023-01-01T00:15:00.000          1037        4.82                  NaN
# 1  2023-01-01T00:15:00.000          1341       16.63                  NaN
# ...

# %%
geometry = [Point(xy) for xy in zip(df['pickup_centroid_longitude'],df['pickup_centroid_latitude'])]
gdfTaxis = gpd.GeoDataFrame(df, geometry=geometry, crs=4326)

# %%
gdfTaxis
# Out:
#                                       trip_id  \
# 0    0fca59218b11688279d795c03c4d16f851f13fa0
# 1    1e539d6e7501164c6b76b761c3152c235e206d59
# 2    2b3c5200439d51f626b60380809bbbcca766a85b
# 3    45b2ea39cfff64d61a46ef016e16f8ee74e9ed23
# 4    464df6aaaf97ca8745985c2a5b2e481067a2bfb6
# ..                                        ...
# 995  feae8e3ae43166b06bbe923d634c849b0bc1e63b
# 996  f9d334bb2cbd0b6bfc72e9a142ac579003ec952e
# 997  f9d478cb58c2cca6ac30ecfd150a2cdce8fe2f67
# 998  fba098fd32d4e1675d9b999ff32f350c121dd841
# 999  a11cec0c91a3bcd1240b6a6379b1212f1f24b810
#
#                                                taxi_id  \
# 0    e2c349c7cbb608d552aa0b5814031943f13641ef9e50d8...
# 1    4ab7a7510c1ebcc9b2e3eaa7bdd6508dbea34da7986aca...
# 2    8c76eb82f069c0731a0049cb78898f02cc5ac6990244c9...
# 3    a688de71e9eb70603ba839dc7faf949968ae3e971e0575...
# 4    8b1a88e5a09cfd55ca72d267f00f56fa50a42aa322bdfe...
# ..                                                 ...
# ...

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf3395 = gdf.to_crs("EPSG:3395")

# %%
gdf
# Out:
#                   name  cartodb_id                       created_at  \
# 0      Grand Boulevard           1 2013-02-02 23:59:44.022000+00:00
# 1         Printers Row           2 2013-02-02 23:59:44.022000+00:00
# 2        United Center           3 2013-02-02 23:59:44.022000+00:00
# 3   Sheffield & DePaul           4 2013-02-02 23:59:44.022000+00:00
# 4        Humboldt Park           5 2013-02-02 23:59:44.022000+00:00
# ..                 ...         ...                              ...
# 93   Ukrainian Village          94 2013-02-02 23:59:44.022000+00:00
# 94            Old Town          95 2013-02-02 23:59:44.022000+00:00
# 95          Gold Coast          96 2013-02-02 23:59:44.022000+00:00
# 96            Boystown          97 2013-02-02 23:59:44.022000+00:00
# 97         River North          98 2013-02-02 23:59:44.022000+00:00
#
#                          updated_at  \
# 0  2013-02-02 23:59:44.295000+00:00
# 1  2013-02-02 23:59:44.295000+00:00
# 2  2013-02-02 23:59:44.295000+00:00
# ...

# %%
gdf['area'] = gdf.area
# Out:
# /tmp/ipykernel_244478/2310586491.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['area'] = gdf.area

# %%
gdf3395
# Out:
#                   name  cartodb_id                       created_at  \
# 0      Grand Boulevard           1 2013-02-02 23:59:44.022000+00:00
# 1         Printers Row           2 2013-02-02 23:59:44.022000+00:00
# 2        United Center           3 2013-02-02 23:59:44.022000+00:00
# 3   Sheffield & DePaul           4 2013-02-02 23:59:44.022000+00:00
# 4        Humboldt Park           5 2013-02-02 23:59:44.022000+00:00
# ..                 ...         ...                              ...
# 93   Ukrainian Village          94 2013-02-02 23:59:44.022000+00:00
# 94            Old Town          95 2013-02-02 23:59:44.022000+00:00
# 95          Gold Coast          96 2013-02-02 23:59:44.022000+00:00
# 96            Boystown          97 2013-02-02 23:59:44.022000+00:00
# 97         River North          98 2013-02-02 23:59:44.022000+00:00
#
#                          updated_at  \
# 0  2013-02-02 23:59:44.295000+00:00
# 1  2013-02-02 23:59:44.295000+00:00
# 2  2013-02-02 23:59:44.295000+00:00
# ...

# %%
gdf3395['area'] = gdf3395.area

# %%
gdf3395.plot("area", legend=True)
# Out:
# <Axes: >

# %%
gdf3395['centroid'] = gdf3395.centroid

# %%
gdf3395 = gdf3395.set_geometry('centroid')
gdf3395.plot("area", legend=True)
# Out:
# <Axes: >

# %%
gdf3395 = gdf3395.set_geometry('geometry')
ax = gdf3395['geometry'].plot()
gdf3395['centroid'].plot(ax = ax, color="orange")
# Out:
# <Axes: >

# %%
gdf3395['convex_hull'] = gdf3395.convex_hull
gdf3395['boundary'] = gdf3395.boundary
ax = gdf3395['convex_hull'].plot(alpha=.5)
gdf3395['boundary'].plot(ax=ax, color="white", linewidth=.3)
# Out:
# <Axes: >

# %%
gdf3395['buffered'] = gdf3395.buffer(500)
gdf3395['buffered_centroid'] = gdf3395['centroid'].buffer(700)
ax = gdf3395['buffered'].plot(alpha=.5)
gdf3395['buffered_centroid'].plot(ax=ax, color="red", alpha=.3)
gdf3395['boundary'].plot(ax=ax, color="white", linewidth=.3)
# Out:
# <Axes: >

# %%
gdf3395
# Out:
#                   name  cartodb_id                       created_at  \
# 0      Grand Boulevard           1 2013-02-02 23:59:44.022000+00:00
# 1         Printers Row           2 2013-02-02 23:59:44.022000+00:00
# 2        United Center           3 2013-02-02 23:59:44.022000+00:00
# 3   Sheffield & DePaul           4 2013-02-02 23:59:44.022000+00:00
# 4        Humboldt Park           5 2013-02-02 23:59:44.022000+00:00
# ..                 ...         ...                              ...
# 93   Ukrainian Village          94 2013-02-02 23:59:44.022000+00:00
# 94            Old Town          95 2013-02-02 23:59:44.022000+00:00
# 95          Gold Coast          96 2013-02-02 23:59:44.022000+00:00
# 96            Boystown          97 2013-02-02 23:59:44.022000+00:00
# 97         River North          98 2013-02-02 23:59:44.022000+00:00
#
#                          updated_at  \
# 0  2013-02-02 23:59:44.295000+00:00
# 1  2013-02-02 23:59:44.295000+00:00
# 2  2013-02-02 23:59:44.295000+00:00
# ...
